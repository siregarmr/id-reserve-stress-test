# %%
import os
os.chdir('/content')
# !rm -rf id-reserve-stress-test
# !git clone https://github.com/siregarmr/id-reserve-stress-test.git
os.chdir('/content/id-reserve-stress-test')
# !pip install -q -r requirements.txt

# %matplotlib inline
from src.api import stress_test
results = stress_test(plot=False)

from src.visualisation import plot_full_report
plot_full_report(results, close_fig=False)
